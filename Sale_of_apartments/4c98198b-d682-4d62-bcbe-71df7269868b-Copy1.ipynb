# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Елизавета, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Привет! Большое спасибо за рекомендации, постараюсь все учесть и использовать в последующих проектах) </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Елизавета, рад тебя видеть =)

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt 
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %% [markdown]
# Выведем первые 20 строк датасета на экран.

# %%
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# Выведем основную информацию о датасете на экран.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Построим общую гистограмму для всех числовых столбцов таблицы.

# %%
data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку `matplotlib.pyplot as plt`
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# На данный момент мы видим, что данные требуют предобработки, в некоторых колонках таблицы имеются пропуски. Делать какие-то выводы на основании таких данных нельзя.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка пропущенных значений.
#
# Найдем количество пропусков в каждом столбце.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# В 14 столбцах есть пропущенные значения. Задача - решить, что делать с пропущенными значениями.
#
# 1. В таблице имеются строки с пропущенными данными о количестве этажей в доме, жилой площади помещения, названии населенного пункта и количестве дней размещения объявления. От таких строк придется избавиться, т.к. данные обязательны нам для исследования и мы не можем заменить пропуски другими значениями, здесь важна точность.

# %%
data = data.dropna(subset=['floors_total', 'living_area', 'days_exposition', 'locality_name'])

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В целом согласен, но будь аккуратно. Таким способом можно удалить не более 10% данных

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           7385
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            16338
# studio                      0
# open_plan                   0
# kitchen_area              704
# balcony                  8115
# locality_name               0
# airports_nearest         4107
# cityCenters_nearest      4087
# parks_around3000         4087
# parks_nearest           12326
# ponds_around3000         4087
# ponds_nearest           11501
# days_exposition             0
# dtype: int64

# %% [markdown]
# 2. Другой столбец с пропущенными значениями — ceiling_height — хранит данные о высоте потолков в квартире. Здесь мы заполним пропуски медианным значением, т.к. метод позволяет максимально приблизиться к истинным значениям, без потери данных.

# %%
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace = True)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            16338
# studio                      0
# open_plan                   0
# kitchen_area              704
# balcony                  8115
# locality_name               0
# airports_nearest         4107
# cityCenters_nearest      4087
# parks_around3000         4087
# parks_nearest           12326
# ponds_around3000         4087
# ponds_nearest           11501
# days_exposition             0
# dtype: int64

# %% [markdown]
# 3. Далее мы видим много пропусков в столбце is_apartment. Скорее всего, если жил площадь не явлляется аппартаментами, то при заполнении продавец ничего не указал в этой графе. В таком случае недостающие значения можно заменить на False.

# %%
data['is_apartment'].fillna('False', inplace = True)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              704
# balcony                  8115
# locality_name               0
# airports_nearest         4107
# cityCenters_nearest      4087
# parks_around3000         4087
# parks_nearest           12326
# ponds_around3000         4087
# ponds_nearest           11501
# days_exposition             0
# dtype: int64

# %% [markdown]
# 4. Пропуски в колонках kitchen_area и balcony заменим на 0, т.к., если продавец ничего не казал в этих графах анкеты, то, скорее всего, балкон и кухня отсутствуют как "отдельные комнаты".

# %%
data['kitchen_area'].fillna(0, inplace = True)
data['balcony'].fillna(0, inplace = True)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4107
# cityCenters_nearest      4087
# parks_around3000         4087
# parks_nearest           12326
# ponds_around3000         4087
# ponds_nearest           11501
# days_exposition             0
# dtype: int64

# %% [markdown]
# 5. Пропуски в столбцах parks_around3000(число парков в радиусе 3 км) и ponds_around3000 (число водоемов в радиусе 3 км) тоже заменим на 0. Если эти графы анкеты пропущены продавцом, очевидно в радиусе 3 км парки и водоемы отсутствуют.

# %%
data['parks_around3000'].fillna(0, inplace = True)
data['ponds_around3000'].fillna(0, inplace = True)

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4107
# cityCenters_nearest      4087
# parks_around3000            0
# parks_nearest           12326
# ponds_around3000            0
# ponds_nearest           11501
# days_exposition             0
# dtype: int64

# %% [markdown]
# 6. Пропуски в оставшихся стобцах также заменим на 0, чтобы не потерять эти данные, потому что это картографические данные, они подтягиваются автоматически, а не добавлены пользователем. Пропуски возникли скорее всего из-за неидеальности программы.
# - airports_nearest(расстояние до ближайшего аэропорта) - может быть равно нулю, т.к. в населенном аэропорте может вовсе не быть аэропорта.
# - cityCenters_nearest ( расстояние до центра города) - не все населенные пункты являются городами, в данных есть, например, поселки.
# - parks_nearest (расстояние до ближайшего парка) - парков в населенном пункте может не быть.
# - ponds_nearest (расстояние до ближайшего водоема) - водоемов в населенном пункте тоже может не быть.
#
# Таким образом если расстояние будет равно нулю, мы будем понимать, что параметр в данном населенном пункте отсутствует, так можно будет исключить данные из выборки.

# %%
data['airports_nearest'].fillna(0, inplace = True)
data['cityCenters_nearest'].fillna(0, inplace = True)
data['parks_nearest'].fillna(0, inplace = True)
data['ponds_nearest'].fillna(0, inplace = True)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущее, смотри, не есть хорошо, когда налево и направо пытаться заполнить пропуски. В реальной работе - сейчас заменил на ноль, а через месяц забыл и среднее подсчитал. Плюс могут быть моменты, когда в продажах, например,  покупка бонусная или подарок, будет ноль стоить. В общем, если можно оставить пропуски пропусками - а тут это можно сделать, то лучше так и сделать, на результаты, даже если мы что-то захотим подсчитать - это не повлияет

# %%
data.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# cityCenters_nearest     0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# dtype: int64

# %% [markdown]
# Работа с пропусками окончена.

# %% [markdown]
# #### Изменение типов данных.

# %% [markdown]
# 1. Приведем данные в first_day_exposition к формату datetime:

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1             2.65          11.0        18.60      1        False  ...
# ...

# %% [markdown]
# 2. Данные в floors_total, parks_around3000, ponds_around3000, days_exposition приведем к типу int. Количество этажей в доме, водоемов и партков рядом, как и количество дней размещения - целые числа.

# %%
data['floors_total'] = data['floors_total'].astype('int')
data['parks_around3000'] = data['parks_around3000'].astype('int')
data['ponds_around3000'] = data['ponds_around3000'].astype('int')
data['days_exposition'] = data['days_exposition'].astype('int')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Столбцы имеют корректный тип данных

# %% [markdown]
# 3. Данные в столбце is_apartment (апартаменты или нет) должны принадлежать к булевому типу по описанию данных в сопроводительных документах.

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')

# %% [markdown]
# Проверим, все ли пошло по плану.

# %%
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1             2.65            11        18.60      1          True  ...
# ...

# %% [markdown]
# #### Устранение дубликатов.

# %% [markdown]
# 1. Проведем поиск неявных дубликатов в столбце с названиями населенных пунктов. Для этого выведем перечень уникальных значений в стобце.

# %%
data['locality_name'].unique()
# Out:
# array(['посёлок Шушары', 'Санкт-Петербург', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Колпино', 'Гатчина',
#        'поселок Мурино', 'деревня Фёдоровское', 'Выборг', 'Кронштадт',
#        'Кировск', 'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Кингисепп', 'Сестрорецк',
#        'деревня Куттузи', 'деревня Заклинье', 'поселок Торковичи',
#        'Красное Село', 'посёлок Понтонный', 'Приозерск', 'село Путилово',
#        'Ивангород', 'Сланцы', 'Шлиссельбург', 'Сясьстрой', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'поселок Новый Свет',
#        'деревня Оржицы', 'деревня Кальтино', 'поселок Романовка',
#        'посёлок Бугры', 'поселок Бугры', 'поселок городского типа Рощино',
# ...

# %% [markdown]
# В результате найдены названия одних и тех же населенных пунктов, написанные разными способами:

# %% [markdown]
# В большинстве случаев дубликаты возникают из-за букв 'е' и 'ё'. Заменим все слова 'поселок' на 'посёлок', слова 'деревня', 'городской посёлок', 'поселок городского типа', 'село' в названии тоже заменим на 'посёлок', что заметно снизит количество дубликатов в названиях

# %%
data['locality_name'] = data['locality_name'].str.replace('поселок', 'посёлок')
data['locality_name'] = data['locality_name'].str.replace('деревня', 'посёлок')
data['locality_name'] = data['locality_name'].str.replace('городской посёлок', 'посёлок')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'посёлок')
data['locality_name'] = data['locality_name'].str.replace('село', 'посёлок')
data['locality_name'].unique()
# Out:
# array(['посёлок Шушары', 'Санкт-Петербург', 'посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'посёлок Кудрово', 'Колпино', 'Гатчина',
#        'посёлок Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'посёлок Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Сиверский', 'посёлок Молодцово',
#        'посёлок городского типа Кузьмоловский', 'Павловск',
#        'посёлок Пикколово', 'Всеволожск', 'Кингисепп', 'Сестрорецк',
#        'посёлок Куттузи', 'посёлок Заклинье', 'посёлок Торковичи',
#        'Красное Село', 'посёлок Понтонный', 'Приозерск',
#        'посёлок Путилово', 'Ивангород', 'Сланцы', 'Шлиссельбург',
#        'Сясьстрой', 'Никольское', 'Зеленогорск', 'Сосновый Бор',
#        'посёлок Новый Свет', 'посёлок Оржицы', 'посёлок Кальтино',
#        'посёлок Романовка', 'посёлок Бугры',
#        'посёлок городского типа Рощино', 'Луга', 'Волосово', 'Отрадное',
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно например вот так:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
#
# </div>

# %% [markdown]
# В результате осталось несколко дубликатов:
# - 'посёлок Кудрово', 'Кудрово'
#
# - 'посёлок станции Вещево', 'посёлок при железнодорожной станции Вещево'
#
# - 'посёлок Приладожский', 'садовое товарищество Приладожский'
#
# - 'садовое товарищество Рахья', 'посёлок Рахья'
#
# - 'Любань', 'посёлок Любань'
#
# - 'посёлок станции Громово', 'посёлок Громово'
#
# Также приведем их к единому виду:

# %%
data['locality_name'] = data['locality_name'].str.replace('посёлок Кудрово', 'Кудрово')
data['locality_name'] = data['locality_name'].str.replace('посёлок станции Вещево', 'посёлок при железнодорожной станции Вещево')
data['locality_name'] = data['locality_name'].str.replace('садовое товарищество Приладожский', 'посёлок Приладожский')
data['locality_name'] = data['locality_name'].str.replace('садовое товарищество Рахья', 'посёлок Рахья')
data['locality_name'] = data['locality_name'].str.replace('Любань', 'посёлок Любань')
data['locality_name'] = data['locality_name'].str.replace('посёлок станции Громово', 'посёлок Громово')
data['locality_name'].unique()
# Out:
# array(['посёлок Шушары', 'Санкт-Петербург', 'посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'Кудрово', 'Колпино', 'Гатчина',
#        'посёлок Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'посёлок Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Сиверский', 'посёлок Молодцово',
#        'посёлок городского типа Кузьмоловский', 'Павловск',
#        'посёлок Пикколово', 'Всеволожск', 'Кингисепп', 'Сестрорецк',
#        'посёлок Куттузи', 'посёлок Заклинье', 'посёлок Торковичи',
#        'Красное Село', 'посёлок Понтонный', 'Приозерск',
#        'посёлок Путилово', 'Ивангород', 'Сланцы', 'Шлиссельбург',
#        'Сясьстрой', 'Никольское', 'Зеленогорск', 'Сосновый Бор',
#        'посёлок Новый Свет', 'посёлок Оржицы', 'посёлок Кальтино',
#        'посёлок Романовка', 'посёлок Бугры',
#        'посёлок городского типа Рощино', 'Луга', 'Волосово', 'Отрадное',
# ...

# %% [markdown]
# #### Обработка аномальных значений.

# %% [markdown]
# Рассмотрим уникальные значения в стобцах с числовыми данными и проверим их на наличие аномалий.

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.65,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,   2.7 ,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   3.2 ,   3.25,   3.45,
#          2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,   3.3 ,   2.47,
#          2.73,   2.84,   3.1 ,   3.4 ,   2.72,   2.54,   2.51,   2.78,
#          2.76,  25.  ,   2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,
#          2.59,   2.  ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.6 ,
#          3.55,   3.16,   3.12,   2.53,   2.96,   2.46,   2.74,   2.45,
#          4.  ,   2.95,   4.06,   2.79,   3.82,   3.53,   2.83,   4.7 ,
#          3.38,   3.65,   3.9 ,   2.71,   3.35,   2.3 ,   3.01,   2.48,
#          2.62,   3.57,   2.82,   3.98,   2.63,   3.83,   3.95,   2.4 ,
#          2.88,   3.87,   3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,
#          4.2 ,   3.75,   4.5 ,   3.68,   8.  ,   2.94,   3.26,   3.34,
#          2.81,   3.07,   3.44,   2.97,   4.37,   2.68,   3.22,   3.27,
# ...

# %% [markdown]
# Мы видим, что в данных о высоте потолков есть странные величины - 25, 26, 27, 27.5 и другие. Скорее всего это ошибка и продавец не поставил точку, отделяющую целую и десятую части в числе. Такие данные мы исправим. Также есть высота потолков 1, 14, 10.3, 8, 8.3 и 100 м - их удалим, здесь ошибка, которую мы не можем исправить, такие значения будут на мешать при исследовании.

# %%
height_wrong = [27.5, 25, 27, 26, 24, 22.6]
height_wright = [2.75, 2.5, 2.7, 2.6, 2.4, 2.26]
data['ceiling_height'] = data['ceiling_height'].replace(height_wrong, height_wright)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше не хардкодить, а использовать функцию или условие: если значение больше 20, то разделить на 10

# %%
data = data[(data['ceiling_height'] != 1) & (data['ceiling_height'] < 6)]

# %%
data['ceiling_height'].unique()
# Out:
# array([2.65, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.7 , 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 3.2 , 3.25, 3.45, 2.77, 2.85, 2.64, 2.57, 4.15, 3.5 ,
#        3.3 , 2.47, 2.73, 2.84, 3.1 , 3.4 , 2.72, 2.54, 2.51, 2.78, 2.76,
#        2.58, 3.7 , 2.52, 5.2 , 2.87, 2.66, 2.59, 2.  , 2.92, 3.11, 3.13,
#        3.8 , 3.15, 3.6 , 3.55, 3.16, 3.12, 2.53, 2.96, 2.46, 2.74, 2.45,
#        4.  , 2.95, 4.06, 2.79, 3.82, 3.53, 2.83, 4.7 , 3.38, 3.65, 3.9 ,
#        2.71, 3.35, 2.3 , 3.01, 2.48, 2.62, 3.57, 2.82, 3.98, 2.63, 3.83,
#        3.95, 2.4 , 2.88, 3.87, 3.66, 3.85, 3.86, 4.19, 3.24, 4.8 , 4.2 ,
#        3.75, 4.5 , 3.68, 2.94, 3.26, 3.34, 2.81, 3.07, 3.44, 2.97, 4.37,
#        2.68, 3.22, 3.27, 3.52, 2.93, 3.46, 3.47, 3.63, 3.33, 3.32, 1.2 ,
#        3.18, 2.98, 4.1 , 2.86, 3.08, 3.17, 4.4 , 3.67, 3.04, 4.45, 3.84,
#        3.09, 3.28, 3.02, 3.36, 3.21, 3.43, 3.23, 3.54, 2.61, 3.06, 3.39,
#        4.65, 3.56, 2.2 , 3.51, 3.93, 3.42, 3.49, 3.14, 3.78, 3.31, 3.88,
# ...

# %%
data['floors_total'].unique()
# Out:
# array([11,  5, 14, 12, 26, 27,  9,  6, 17, 16, 25,  3, 23, 19, 18,  4, 24,
#         8, 10,  7, 15,  2, 22, 13, 20, 28, 36, 21, 35, 34, 60,  1, 29, 33,
#        52, 37])

# %%
data['floor'].unique()
# Out:
# array([ 1,  4, 13,  5,  6, 26,  7,  3,  2,  8, 11, 15,  9, 18, 22, 10, 19,
#        20, 27, 25, 17, 14, 12, 21, 28, 24, 16, 23, 32, 33, 31])

# %%
data['rooms'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  0,  6,  7,  8, 14, 15,  9, 11, 19, 10, 16, 12])

# %%
data['balcony'].unique()
# Out:
# array([2., 0., 1., 5., 4., 3.])

# %% [markdown]
# Проверим, что за квартира с 5 балконами

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет: Рекомендую не смотреть данные "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их (если они соответствуют здравому смыслу). В этом поможет метод boxplot()
# </div>

# %%
data[data['balcony'] == 5]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 41               16   7900000.0       74.00           2016-05-04      3
# 42               13  22000000.0      161.80           2015-07-08      4
# 267               2  14700000.0      120.00           2018-09-07      3
# 371              11   7300000.0       65.00           2018-09-12      2
# 409               5   6600000.0       73.00           2017-08-15      3
# ...             ...         ...         ...                  ...    ...
# 23105             2  11000000.0      112.00           2018-03-01      4
# 23114             6   7300000.0      102.00           2017-11-16      3
# 23147             8   5780000.0       55.00           2017-11-23      2
# 23526            14   5800000.0       60.69           2018-03-13      3
# 23549             5  19600000.0      184.00           2016-04-21      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Получилось 228 строк квартир с 5 балконами, вряд ли в квартире плошадью 55 кв.м есть 5 балконов. Удалим такие строки.

# %%
data = data[data['balcony'] != 5]

# %% [markdown]
# Проверим наличие дубликатов в таблице.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>

# %% [markdown]
# #### Вывод:
# В результате предобработки данные приведены в состояние, позволяющее их дальнейшее изучение - изменены типы данных в некоторых столбцах, устранены все дубликаты, пропущенные и аномальные значения также устранены. Данные полностью готовы к дальнейшей работе.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Вывод добавила.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# ####  Столбец "цена одного квадратного метра"
# Далее добавим в таблицу столбец с указанием цены за 1 кв.м. площади. Для этого цену каждого объекта недвижимости разделим на его площадь.

# %%
data['one_meter_price'] = data['last_price'] / data['total_area']
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# 13            20   3550000.0       42.80           2017-07-01      2
# 14             1   4400000.0       36.00           2016-06-23      1
# 15            16   4650000.0       39.00           2017-11-18      1
# ...

# %% [markdown]
# ####  Столбец "день недели публикации объявления"

# %%
data['day_of_week'] = data['first_day_exposition'].dt.day_name()
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 4             2  10000000.0       100.0           2018-06-19      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1            2.65            11         18.6      1          True  ...
# 2            2.65             5         34.3      4          True  ...
# 4            3.03            14         32.0     13          True  ...
# 5            2.65            12         14.4      5          True  ...
# 6            2.65            26         10.6      6          True  ...
#
#        locality_name  airports_nearest  cityCenters_nearest  parks_around3000  \
# ...

# %% [markdown]
# ####  Столбец "месяц публикации объявления"

# %%
data['month_exposition'] = data['first_day_exposition'].dt.month_name()
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 4             2  10000000.0       100.0           2018-06-19      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1            2.65            11         18.6      1          True  ...
# 2            2.65             5         34.3      4          True  ...
# 4            3.03            14         32.0     13          True  ...
# 5            2.65            12         14.4      5          True  ...
# 6            2.65            26         10.6      6          True  ...
#
#    airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# ...

# %% [markdown]
# ####  Столбец "год публикации объявления"

# %%
data['year_exposition'] = data['first_day_exposition'].dt.year
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 4             2  10000000.0       100.0           2018-06-19      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 1            2.65            11         18.6      1          True  ...
# 2            2.65             5         34.3      4          True  ...
# 4            3.03            14         32.0     13          True  ...
# 5            2.65            12         14.4      5          True  ...
# 6            2.65            26         10.6      6          True  ...
#
#    cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://runebook.dev/ru/docs/numpy/reference/arrays.datetime
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спасибо!.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %% [markdown]
# ####  Столбец "тип этажа квартиры"

# %%
def categorize_type(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
data['type_of_floor'] = data.apply(categorize_type, axis=1)
data.head(20)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40           2018-12-04      1
# 2             10   5196000.0       56.00           2015-08-20      2
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 6              6   3700000.0       37.30           2017-11-02      1
# 8             20   2900000.0       33.16           2018-05-23      1
# 9             18   5400000.0       61.00           2017-02-26      3
# 10             5   5050000.0       39.60           2017-11-16      1
# 11             9   3300000.0       44.00           2018-08-27      2
# 12            10   3890000.0       54.00           2016-06-30      2
# 13            20   3550000.0       42.80           2017-07-01      2
# 14             1   4400000.0       36.00           2016-06-23      1
# 15            16   4650000.0       39.00           2017-11-18      1
# ...

# %% [markdown]
# ####  Перевод расстояния до центра города, до аэропорта и до парков/водоемов в километры

# %%
data['cityCenters_nearest'] = (data['cityCenters_nearest']/1000).round()
data['cityCenters_nearest'].head()
# Out:
# 1    19.0
# 2    14.0
# 4     8.0
# 5     0.0
# 6    19.0
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует округление. Добавь, пожалуйста

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Округление добавила. Я, на самом деле упустила, что здесь нужно округлить км, и сделала округление в последнем задании. </div>

# %%
data['airports_nearest'] = data['airports_nearest']/1000

# %%
data['parks_nearest'] = data['parks_nearest']/1000

# %%
data['ponds_nearest'] = data['ponds_nearest']/1000

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Построим гистограммы для некоторых столбцов из таблицы и изучим их

# %%
data['total_area'].hist(bins=100, range=(0, 400))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы советовал сократить range и тогда мы сможем увидеть пиковые значения.
# </div>

# %% [markdown]
# Большая часть квартир площадью около 50 кв.м.

# %%
data['living_area'].hist(bins=100, range=(0, 200))
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].hist(bins=100, range=(0, 200))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist(bins=100, range=(0, 10000000))
# Out:
# <AxesSubplot:>

# %%
data['rooms'].hist(bins=100, range=(0, 10))
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].hist(bins=100, range=(0, 10))
# Out:
# <AxesSubplot:>

# %%
data['floor'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %%
data['type_of_floor'].hist(bins=100, range=(0, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data['floors_total'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %%
data['cityCenters_nearest'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Здесь мы видим большое количество значений равных 0, т.к. мы заменили все пропуски на 0.

# %%
data['airports_nearest'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %%
data['airports_nearest'].hist(bins=100, range=(0, 100))
# Out:
# <AxesSubplot:>

# %%
data['parks_nearest'].hist(bins=100, range=(0, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Нет решения по дню, месяцу. Добавь, пожалуйста

# %%
data['day_of_week'].hist(bins=100, range=(0, 7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Объявления о продаже квартир чаще всего выкладывают в будние дни, на выходные приходится почти в 2 раза меньше объявлений.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Подскажи, пожалуйста, можно ли как-то сделать так, чтобы график строился начиная с понедельника и дальше дни недели по порядку (и так же с месяцами)? И как сделать, чтобы названия не накладывались друг на друга? Я думала как вариант исправить код вверху, где я создавала этот столбец, чтобы день недели, как и месяц отображался цифрой, а не наименованием, но привычные названия, как будто, удобнее. </div>

# %%
data['month_exposition'].hist(bins=100, range=(0, 12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большее количество объявлений выкладывают в осенне-зимний период, меньше летом и в "праздничные" месяцы - май, январь, декабрь.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Дни и месяцы добавила.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# В мае не до продаж, все на огородах =)

# %%
data['days_exposition'].hist(bins=100, range=(0, 1000))
# Out:
# <AxesSubplot:>

# %% [markdown]
# На гистограмме видно, что большая часть квартир продавалась в течение 100 дней с даты публикации. Вычислим среднее и медианное значение для данного параметра

# %%
data['days_exposition'].mean()
# Out:
# 184.8742359495862

# %%
data['days_exposition'].median()
# Out:
# 101.0

# %% [markdown]
# Медианное значение срока продажи квартир составило 101 день.Большая часть квартир продается именно за этот период. Резкий спад наблюдается примерно после 200 дней. Такие продажи можно считать необычно долгими.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данных с помощью boxplot() или describe().
# </div>

# %% [markdown]
# В таком случае быстрыми продажами можно считать 0 - 44 дней (от края "усов" до 1-го квартиля), а необычно долгими все, что дольше 238 дней (от 3-го квартиля).

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Попробовала оба метода для наглядности, немного западает эта тема, не уверена, что правильно распределила. Правильно, что все, что в пределах "усов" - это норма, остальное выбросы, но 50% выборки сосредоточено внутри 1-3 квартилей? А все, что за их пределами, дольше/медленнее обычного?  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, до 1.5 месяцев можно назвать быстрой продажей

# %%
plt.ylim(-100, 1000)
data.boxplot('days_exposition')
# Out:
# <AxesSubplot:>

# %%
data.days_exposition.describe()
# Out:
# count    18487.000000
# mean       184.874236
# std        221.656986
# min          1.000000
# 25%         44.000000
# 50%        101.000000
# 75%        238.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# #### Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %% [markdown]
# Построим графики зависимости стоимости квартиры от:
#   - общей площади;
#   - жилой площади;
#   - площади кухни;
#   - количество комнат;
#   - типа этажа, на котором расположена квартира (первый, последний, другой);
#   - даты размещения (день недели, месяц, год);

# %%
data_filtered = data[['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms', 'type_of_floor', 'day_of_week', 'month_exposition', 'year_exposition']]
data_filtered.head()
# Out:
#    last_price  total_area  living_area  kitchen_area  rooms type_of_floor  \
# 1   3350000.0        40.4         18.6          11.0      1        первый
# 2   5196000.0        56.0         34.3           8.3      2        другой
# 4  10000000.0       100.0         32.0          41.0      2        другой
# 5   2890000.0        30.4         14.4           9.1      1        другой
# 6   3700000.0        37.3         10.6          14.4      1        другой
#
#   day_of_week month_exposition  year_exposition
# 1     Tuesday         December             2018
# 2    Thursday           August             2015
# 4     Tuesday             June             2018
# 5      Monday        September             2018
# 6    Thursday         November             2017

# %%
pd.plotting.scatter_matrix(data_filtered, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:xlabel='last_price', ylabel='last_price'>,
#         <AxesSubplot:xlabel='total_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='living_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='rooms', ylabel='last_price'>,
#         <AxesSubplot:xlabel='year_exposition', ylabel='last_price'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='total_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='living_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='year_exposition', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='last_price', ylabel='living_area'>,
#         <AxesSubplot:xlabel='total_area', ylabel='living_area'>,
# ...

# %%
data_filtered.plot(x='total_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='last_price'>

# %% [markdown]
# Для определения зависимости двух факторов также добавим вычисление коэффициента корреляции Пирсона. Чем ближе коэффициент к -1 или 1, тем больше зависимость.

# %%
data_filtered['total_area'].corr(data_filtered['last_price'])
# Out:
# 0.6295358102645029

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость переменных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Давай графики зависимостей подкрепим корреляцией Пирсона и сразу интерпретировать полученные данные в разделе?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавила после каждого графика вычисление коэффициента корреляции, кроме этажей, дней, месяцев, лет - не вычисляется корреляция. Не совсем поняла, как быть в таком случае? </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Корреляцию есть смысл рассчитывать только для нелинейных данных (в нашем случае это площади)
# </div>

# %%
data_filtered.plot(x='living_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='living_area', ylabel='last_price'>

# %%
data_filtered['living_area'].corr(data_filtered['last_price'])
# Out:
# 0.5541627032866981

# %%
data_filtered.plot(x='kitchen_area', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='kitchen_area', ylabel='last_price'>

# %%
data_filtered['kitchen_area'].corr(data_filtered['last_price'])
# Out:
# 0.4094411056778421

# %%
data_filtered.plot(x='rooms', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='last_price'>

# %%
data_filtered['rooms'].corr(data_filtered['last_price'])
# Out:
# 0.35229550871677257

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Зависимости прерывных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)
# </div>

# %% [markdown]
# data.describe()

# %%
data_filtered.plot(x='type_of_floor', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='type_of_floor', ylabel='last_price'>

# %%
data_filtered.plot(x='day_of_week', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='last_price'>

# %%
data_filtered.plot(x='month_exposition', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='month_exposition', ylabel='last_price'>

# %%
data_filtered.plot(x='year_exposition', y='last_price', kind='scatter')
# Out:
# <AxesSubplot:xlabel='year_exposition', ylabel='last_price'>

# %% [markdown]
# На основании графиков видно, что на стоимость квартир в большей степени влияют площади как самой квартиры, так и жилой площади,  кухни. Также влияет количество комнат. Что касается времени года, то большая стоимость у квартир, выложенных в весенний период.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Зависимости прерывных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)
# </div>

# %% [markdown]
# #### Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %% [markdown]
# 1. Сделаем сортировку данных по населеннным пунктам по убыванию количества объявлений.

# %%
data_locality_name = data[['locality_name', 'one_meter_price']].groupby('locality_name')
data_locality_name.count().sort_values(by='one_meter_price', ascending=False).head(10)
# Out:
#                    one_meter_price
# locality_name
# Санкт-Петербург              12418
# посёлок Мурино                 480
# Кудрово                        388
# посёлок Шушары                 371
# Всеволожск                     311
# Колпино                        292
# Пушкин                         286
# посёлок Парголово              277
# Гатчина                        248
# Петергоф                       172

# %% [markdown]
# Посчитаем медиану стоимости кв.м. в 10 населённых пунктах с наибольшим числом объявлений.

# %%
names = data.groupby('locality_name')['locality_name'].count().sort_values(ascending=False).head(10).index
data_name_meter_price = data[data['locality_name'].isin(names)]
data_name_meter_price.groupby('locality_name', as_index=False)['one_meter_price'].mean()
# Out:
#        locality_name  one_meter_price
# 0         Всеволожск     68855.068983
# 1            Гатчина     67634.486562
# 2            Колпино     74649.671686
# 3            Кудрово     94907.735879
# 4           Петергоф     82803.504164
# 5             Пушкин    102530.039643
# 6    Санкт-Петербург    111846.872134
# 7     посёлок Мурино     86389.173638
# 8  посёлок Парголово     89816.024436
# 9     посёлок Шушары     78438.463757

# %% [markdown]
# На основании получившейся таблицы, можно заметить, что наиболее высокая цена за кв.м. в Санкт-Петербурге и Пушкине.Самая никая - в Гатчине.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Смотри,  как можно в 1 строку:

# %%
data.groupby('locality_name').agg({'balcony':'count', 'last_price':'median'}) \
    .sort_values(by = 'balcony', ascending = False) \
    .head(10)
# Out:
#                    balcony  last_price
# locality_name
# Санкт-Петербург      12418   5300000.0
# посёлок Мурино         480   3400000.0
# Кудрово                388   3750000.0
# посёлок Шушары         371   3885000.0
# Всеволожск             311   3330000.0
# Колпино                292   3500000.0
# Пушкин                 286   5100000.0
# посёлок Парголово      277   4000000.0
# Гатчина                248   3000000.0
# Петергоф               172   3600000.0

# %% [markdown]
# #### Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# Округлим данные по расстоянию до целого числа. Подсчитаем медианное значение по каждому км. Построим график.

# %%
data['cityCenters_nearest_km'] = data['cityCenters_nearest'].round()
data['km_price'] = data['last_price']/data['total_area']
data_spb = data[(data['locality_name']=='Санкт-Петербург') & (data['cityCenters_nearest']!=0)].copy()
data_spb.groupby('cityCenters_nearest_km')[['km_price']].mean()
# Out:
#                              km_price
# cityCenters_nearest_km
# 1.0                     161878.466408
# 2.0                     157804.332462
# 3.0                     116109.424027
# 4.0                     130843.891830
# 5.0                     135844.961626
# 6.0                     144936.695556
# 7.0                     150103.613523
# 8.0                     121960.978295
# 9.0                     110428.283230
# 10.0                    109770.204069
# 11.0                    106332.472015
# 12.0                    105859.774081
# 13.0                    106176.015297
# 14.0                    102628.670532
# 15.0                    101914.562967
# 16.0                     98848.858227
# 17.0                     96208.797388
# 18.0                     95159.903214
# 19.0                     98612.599504
# 20.0                     99807.651866
# 21.0                     89813.506369
# 22.0                     88674.508658
# 23.0                     90904.226014
# ...

# %%
data_spb.groupby('cityCenters_nearest_km')[['km_price']].mean().plot(style='o-', grid = True, title = 'Заголовок');

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. В твой код добавил заголовок и сетку, посмотри, пожалуйста, этот момент. Очень важно оформлять графики
# </div>

# %% [markdown]
# На графике видно, что наиболее высокая цена у квартир, находящихся в центре и близко к нему, не дальше 7 км. За этими пределами цена квартир падает. Также мы видим всплеск в районе 27 км от центра. Возможно здесь находитя элитная загородная недвижимость.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# #### Этап 1. Предобработка данных.
# Прежде чем анализировать данные, необходимо было их проверить на наличие пропусков и дубликатов, и привести в состояние, подходящее для анализа. В данном этапе были проведены следующие действия:
#
# 1. Поиск и обработка пропущенных значений. Замена пропущенных значений медианным значением, удаление строк с пропусками, если они будут мешать дальнейшему анализу, заполнение 0.
# 2. Изменение типо данных в некоторых столбцах, также данные приведены к единому региструдля более удобной работы с ними.
# 3. Поиск и удаление всех неявных дубликатов в названиях населенных пунктов.
# 4. Поиск и и устранение редких и выбивающихся значений.
# 5. Добавлены в таблицу новые столбцы со следующими параметрами:
#    - цена одного квадратного метра;
#    - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
#    - месяц публикации объявления;
#    - год публикации объявления;
#    - тип этажа квартиры (значения — «первый», «последний», «другой»);
#    - расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).
# Эти данные понадобились нам для дальнейшего исследования.
#
# #### Этап 2. Исследование данных в соответствии с поставленными вопросами.
# Для поиска ответов на следующие вопросы было произведены вычисления и построены графики/диаграммы, а так же изучены некоторые параметры (площади, цена, эаж, общее количество этажей, удаленность от центра и др.). Такие результаты мы получили.
#
# ##### Как быстро продавались квартиры? Какие продажи можно считать быстрыми, а какие — необычно долгими?
# В среднем квартиры продаются в срок до 101 дня. В норме продажи до ~520 дней. Быстрыми продажами можно считать 0 - 44 дней (от края "усов" до 1-го квартиля), а необычно долгими все, что дольше 238 дней (от 3-го квартиля).
#
# ##### Есть ли зависимость цены от общей площади, жилой площади, площади кухни, количества комнат, этажа, на котором расположена квартира (первый, последний, другой), даты размещения (день недели, месяц, год)?
# Да, на стоимость квартир в большей степени влияют площади как самой квартиры, так и жилой площади, кухни. Также влияет количество комнат. Что касается времени года, то большая стоимость у квартир, выложенных в весенний период.
#
# ##### В каких населённых пункта самая высокая и низкая стоимость квадратного метра (из 10 с наибольшим числом объявлений)?
# Наиболее высокая цена за кв.м. в Санкт-Петербурге и Пушкине.Самая никая - в Гатчине.
#
#
# ##### Как влияет расстояние до центра города на стоимость квартир в Санкт-Петербурге? Какова средняя цена каждого километра?
# Наиболее высокая цена у квартир, находящихся в центре и близко к нему, не дальше 7 км. За этими пределами цена квартир падает. Цена 1 километра ~ 253 т. - 150 т. в центральной части города.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Округление
#
# 2) Шаг 4.1 (день, месяц)
#
# 3) Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# 4) Корреляция Пирсона
#
# 5) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 6) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [ ]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [ ]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [ ]  в каждом этапе есть промежуточные выводы
# - [ ]  есть общий вывод
